# %%
a, b = 5, 10

# %%
print(a, '>', b, '=', a > b)
# Out:
# 5 > 10 = False

# %%
print(a, '<', b, '=', a < b)
# Out:
# 5 < 10 = True

# %%
print(a, '==', b, '=', a == b)
# Out:
# 5 == 10 = False

# %%
print( a, '!=', b, '=', a != b)
# Out:
# 5 != 10 = True

# %%
print(a, '>=', b, '=', a >= b)
# Out:
# 5 >= 10 = False

# %%
print(a, '<=', b, '=', a <= b)
# Out:
# 5 <= 10 = True
