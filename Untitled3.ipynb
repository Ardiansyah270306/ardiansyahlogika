# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# # [Putra ***Petar***](https://)
#
# > Tambahkan blockquote
#
# > `Tambahkan blockquote`
#
# 1.   Item daftar
#
# blockq
#
#
# *   Item daftar
