# %%
list_buah = ['Duren', 'Jambu', 'Pisang', 'Apel']

# %%
print('list_buah:' ,list_buah)
# Out:
# list_buah: ['Duren', 'Jambu', 'Pisang', 'Apel']

# %%
print(list_buah[-1])
print(list_buah[-2])
print(list_buah[-3])
print(list_buah[-4])
# Out:
# Apel
# Pisang
# Jambu
# Duren

# %%
print(list_buah[1:3])
# Out:
# ['Jambu', 'Pisang']

# %%
list_buah[3]= 'Timah Topas'

# %%
print(list_buah)
# Out:
# ['Duren', 'Jambu', 'Pisang', 'Timah Topas']

# %%
list_buah.append('Timah Kasar')

# %%
print(list_buah)
# Out:
# ['Duren', 'Jambu', 'Pisang', 'Timah Topas', 'Timah Kasar']

# %%
list_buah.insert(0, 'Merah')

# %%
print(list_buah)
# Out:
# ['Merah', 'Duren', 'Jambu', 'Pisang', 'Timah Topas', 'Timah Kasar']

# %%
list_buah.pop()
# Out:
# 'Timah Kasar'

# %%
print(list_buah)
# Out:
# ['Merah', 'Duren', 'Jambu', 'Pisang', 'Timah Topas']

# %%
list_buah.pop()
# Out:
# 'Timah Topas'

# %%
print(list_buah)
# Out:
# ['Merah', 'Duren', 'Jambu', 'Pisang']

# %%
list_buah.remove('Merah')

# %%
print(list_buah)
# Out:
# ['Duren', 'Jambu', 'Pisang']

# %%
del list_buah[0]

# %%
print(list_buah)
# Out:
# ['Jambu', 'Pisang']

# %%
list_buah.sort()

# %%
print(list_buah)
# Out:
# ['Jambu', 'Pisang']
