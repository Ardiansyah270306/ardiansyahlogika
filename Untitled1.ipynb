# %%
Print("hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e94fdc0344b> in <cell line: 1>()
# ----> 1 Print("hello world")
#
# NameError: name 'Print' is not defined
