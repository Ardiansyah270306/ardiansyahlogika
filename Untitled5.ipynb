# %%
a = 10

# %%
print('a = 10 -> ', a)
# Out:
# a = 10 ->  10

# %%
a += 5

# %%
print( 'a +- 5 -> ', a)
# Out:
# a +- 5 ->  15

# %%
a -= 3

# %%
print('a -= 3 -> ', a)
# Out:
# a -= 3 ->  12

# %%
a *- 6
# Out:
# -72

# %%
print('a *= 6 -> ', a)
# Out:
# a *= 6 ->  12

# %%
a /- 8
# Out:
# -1.5

# %%
print('a /= 8 ->', a)
# Out:
# a /= 8 -> 12
