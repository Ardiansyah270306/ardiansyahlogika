# %%
a = int(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8941b20ea7e0> in <cell line: 1>()
# ----> 1 a = int(a)
#
# NameError: name 'a' is not defined

# %%
a %= 9
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f929f3d35785> in <cell line: 1>()
# ----> 1 a %= 9
#
# NameError: name 'a' is not defined
